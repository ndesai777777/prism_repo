# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Genrocket_10k_seed1_causal_revised.csv')
print(f'Shape: {df.shape}')
print(f'\nColumns ({len(df.columns)}):')
print(list(df.columns))
