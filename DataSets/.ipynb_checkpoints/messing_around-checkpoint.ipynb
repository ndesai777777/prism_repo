# %% [markdown]
# # PRISM Distribution Validation — Per-Variable Inspection
#
# This notebook validates each of the 42 variables from `Genrocket_dataset_10k_seed1.csv`
# against expected distributions from the GenRocket review PDF.
# Each variable has its own cell for visual verification.

# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv('Genrocket_dataset_10k_seed1.csv', low_memory=False)
# Drop junk columns and map GenRocket column names to expected names
df = df[[c for c in df.columns if not c.startswith('Unnamed')]]
df = df.rename(columns={
    'Clinical Score': 'percolator_clinical_score',
    'SDOH Score': 'percolator_sdoh_score',
    'utilization_score': 'percolator_utilization_score',
    'currentRiskScore': 'current_risk_score',
})
# If current_risk_score is still missing, check for alternatives
if 'current_risk_score' not in df.columns and 'currentRiskScore' in df.columns:
    df = df.rename(columns={'currentRiskScore': 'current_risk_score'})
print(f'Dataset shape: {df.shape}')
print(f'Columns ({len(df.columns)}): {list(df.columns)}')

results = []

# %% [markdown]
# ---
# ## Binary Flag Variables
# Each cell shows value_counts (raw + percentage) and checks against expected range.

# %% [markdown]
# ### anxiety_flag — Expected: 18%-28% of members = 1

# %%
# anxiety_flag — Expected: 18%-28% of members = 1
print('anxiety_flag value counts:')
print(df['anxiety_flag'].value_counts())
print()
print('Percentage:')
print((df['anxiety_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['anxiety_flag'].mean()*100:.1f}%")
print(f'Expected range: 18.0% - 28.0%')

# %% [markdown]
# ### asthma_flag — Expected: 12%-18% of members = 1

# %%
# asthma_flag — Expected: 12%-18% of members = 1
print('asthma_flag value counts:')
print(df['asthma_flag'].value_counts())
print()
print('Percentage:')
print((df['asthma_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['asthma_flag'].mean()*100:.1f}%")
print(f'Expected range: 12.0% - 18.0%')

# %% [markdown]
# ### behavioral_health_risk_flag — Expected: 20%-30% of members = 1

# %%
# behavioral_health_risk_flag — Expected: 20%-30% of members = 1
print('behavioral_health_risk_flag value counts:')
print(df['behavioral_health_risk_flag'].value_counts())
print()
print('Percentage:')
print((df['behavioral_health_risk_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['behavioral_health_risk_flag'].mean()*100:.1f}%")
print(f'Expected range: 20.0% - 30.0%')

# %% [markdown]
# ### chf_flag — Expected: 11.5%-16.5% of members = 1

# %%
# chf_flag — Expected: 11.5%-16.5% of members = 1
print('chf_flag value counts:')
print(df['chf_flag'].value_counts())
print()
print('Percentage:')
print((df['chf_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['chf_flag'].mean()*100:.1f}%")
print(f'Expected range: 11.5% - 16.5%')

# %% [markdown]
# ### ckd_flag — Expected: 12.5%-17.5% of members = 1

# %%
# ckd_flag — Expected: 12.5%-17.5% of members = 1
print('ckd_flag value counts:')
print(df['ckd_flag'].value_counts())
print()
print('Percentage:')
print((df['ckd_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['ckd_flag'].mean()*100:.1f}%")
print(f'Expected range: 12.5% - 17.5%')

# %% [markdown]
# ### copd_flag — Expected: 8.5%-13.5% of members = 1

# %%
# copd_flag — Expected: 8.5%-13.5% of members = 1
print('copd_flag value counts:')
print(df['copd_flag'].value_counts())
print()
print('Percentage:')
print((df['copd_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['copd_flag'].mean()*100:.1f}%")
print(f'Expected range: 8.5% - 13.5%')

# %% [markdown]
# ### depression_flag — Expected: 20%-30% of members = 1

# %%
# depression_flag — Expected: 20%-30% of members = 1
print('depression_flag value counts:')
print(df['depression_flag'].value_counts())
print()
print('Percentage:')
print((df['depression_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['depression_flag'].mean()*100:.1f}%")
print(f'Expected range: 20.0% - 30.0%')

# %% [markdown]
# ### diabetes_flag — Expected: 25.5%-30.5% of members = 1

# %%
# diabetes_flag — Expected: 25.5%-30.5% of members = 1
print('diabetes_flag value counts:')
print(df['diabetes_flag'].value_counts())
print()
print('Percentage:')
print((df['diabetes_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['diabetes_flag'].mean()*100:.1f}%")
print(f'Expected range: 25.5% - 30.5%')

# %% [markdown]
# ### dual_eligible — Expected: 18%-25% of members = 1

# %%
# dual_eligible — Expected: 18%-25% of members = 1
print('dual_eligible value counts:')
print(df['dual_eligible'].value_counts())
print()
print('Percentage:')
print((df['dual_eligible'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['dual_eligible'].mean()*100:.1f}%")
print(f'Expected range: 18.0% - 25.0%')

# %% [markdown]
# ### food_insecurity_flag — Expected: 15%-25% of members = 1

# %%
# food_insecurity_flag — Expected: 15%-25% of members = 1
print('food_insecurity_flag value counts:')
print(df['food_insecurity_flag'].value_counts())
print()
print('Percentage:')
print((df['food_insecurity_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['food_insecurity_flag'].mean()*100:.1f}%")
print(f'Expected range: 15.0% - 25.0%')

# %% [markdown]
# ### high_cost_drug_flag — Expected: 5%-10% of members = 1

# %%
# high_cost_drug_flag — Expected: 5%-10% of members = 1
print('high_cost_drug_flag value counts:')
print(df['high_cost_drug_flag'].value_counts())
print()
print('Percentage:')
print((df['high_cost_drug_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['high_cost_drug_flag'].mean()*100:.1f}%")
print(f'Expected range: 5.0% - 10.0%')

# %% [markdown]
# ### housing_instability_flag — Expected: 8%-15% of members = 1

# %%
# housing_instability_flag — Expected: 8%-15% of members = 1
print('housing_instability_flag value counts:')
print(df['housing_instability_flag'].value_counts())
print()
print('Percentage:')
print((df['housing_instability_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['housing_instability_flag'].mean()*100:.1f}%")
print(f'Expected range: 8.0% - 15.0%')

# %% [markdown]
# ### opioid_flag — Expected: 5%-10% of members = 1

# %%
# opioid_flag — Expected: 5%-10% of members = 1
print('opioid_flag value counts:')
print(df['opioid_flag'].value_counts())
print()
print('Percentage:')
print((df['opioid_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['opioid_flag'].mean()*100:.1f}%")
print(f'Expected range: 5.0% - 10.0%')

# %% [markdown]
# ### polypharmacy_flag — Expected: 15%-25% of members = 1

# %%
# polypharmacy_flag — Expected: 15%-25% of members = 1
print('polypharmacy_flag value counts:')
print(df['polypharmacy_flag'].value_counts())
print()
print('Percentage:')
print((df['polypharmacy_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['polypharmacy_flag'].mean()*100:.1f}%")
print(f'Expected range: 15.0% - 25.0%')

# %% [markdown]
# ### pregnancy_flag — Expected: 3%-6% of members = 1

# %%
# pregnancy_flag — Expected: 3%-6% of members = 1
print('pregnancy_flag value counts:')
print(df['pregnancy_flag'].value_counts())
print()
print('Percentage:')
print((df['pregnancy_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['pregnancy_flag'].mean()*100:.1f}%")
print(f'Expected range: 3.0% - 6.0%')

# %% [markdown]
# ### substance_use_flag — Expected: 8%-15% of members = 1

# %%
# substance_use_flag — Expected: 8%-15% of members = 1
print('substance_use_flag value counts:')
print(df['substance_use_flag'].value_counts())
print()
print('Percentage:')
print((df['substance_use_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['substance_use_flag'].mean()*100:.1f}%")
print(f'Expected range: 8.0% - 15.0%')

# %% [markdown]
# ### transportation_barrier_flag — Expected: 12%-20% of members = 1

# %%
# transportation_barrier_flag — Expected: 12%-20% of members = 1
print('transportation_barrier_flag value counts:')
print(df['transportation_barrier_flag'].value_counts())
print()
print('Percentage:')
print((df['transportation_barrier_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['transportation_barrier_flag'].mean()*100:.1f}%")
print(f'Expected range: 12.0% - 20.0%')

# %% [markdown]
# ### utilities_insecurity_flag — Expected: 9.5%-14.5% of members = 1

# %%
# utilities_insecurity_flag — Expected: 9.5%-14.5% of members = 1
print('utilities_insecurity_flag value counts:')
print(df['utilities_insecurity_flag'].value_counts())
print()
print('Percentage:')
print((df['utilities_insecurity_flag'].value_counts(normalize=True) * 100).round(1))
print(f"\nProportion of 1s: {df['utilities_insecurity_flag'].mean()*100:.1f}%")
print(f'Expected range: 9.5% - 14.5%')

# %% [markdown]
# ---
# ## Bucketed Numeric Variables
# Each cell shows bucketed value_counts (raw + percentage) and compares to expected distribution.

# %% [markdown]
# ### admits_last_6m — Expected: 0: 85%, 1: 10%, 2: 3%, 3+: 2%

# %%
# admits_last_6m — Expected: 0: 85%, 1: 10%, 2: 3%, 3+: 2%
bucketed = df['admits_last_6m'].clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'})
print('admits_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(['0', '1', '2', '3+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['0', '1', '2', '3+']) * 100).round(1))
print('\nExpected: 0: 85%, 1: 10%, 2: 3%, 3+: 2%')

# %% [markdown]
# ### age — Expected: 18-34: 20%, 35-49: 25%, 50-64: 35%, 65+: 20%

# %%
# age — Expected: 18-34: 20%, 35-49: 25%, 50-64: 35%, 65+: 20%
bucketed = pd.cut(df['age'], bins=[17, 34, 49, 64, 200], labels=['18-34', '35-49', '50-64', '65+'])
print('age bucketed value counts:')
print(bucketed.value_counts().reindex(['18-34', '35-49', '50-64', '65+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['18-34', '35-49', '50-64', '65+']) * 100).round(1))
print('\nExpected: 18-34: 20%, 35-49: 25%, 50-64: 35%, 65+: 20%')

# %% [markdown]
# ### ed_visits_last_30d — Expected: 0: 92%, 1: 6%, 2: 1.5%, 3+: 0.5%

# %%
# ed_visits_last_30d — Expected: 0: 92%, 1: 6%, 2: 1.5%, 3+: 0.5%
bucketed = df['ed_visits_last_30d'].clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'})
print('ed_visits_last_30d bucketed value counts:')
print(bucketed.value_counts().reindex(['0', '1', '2', '3+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['0', '1', '2', '3+']) * 100).round(1))
print('\nExpected: 0: 92%, 1: 6%, 2: 1.5%, 3+: 0.5%')

# %% [markdown]
# ### ed_visits_last_6m — Expected: 0: 70%, 1: 15%, 2: 8%, 3+: 7%

# %%
# ed_visits_last_6m — Expected: 0: 70%, 1: 15%, 2: 8%, 3+: 7%
bucketed = df['ed_visits_last_6m'].clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'})
print('ed_visits_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(['0', '1', '2', '3+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['0', '1', '2', '3+']) * 100).round(1))
print('\nExpected: 0: 70%, 1: 15%, 2: 8%, 3+: 7%')

# %% [markdown]
# ### living_alone_flag — Expected: 0: 74%, 1: 23%, Unknown: 3%

# %%
# living_alone_flag — Expected: 0: 74%, 1: 23%, Unknown: 3%
print('living_alone_flag value counts (raw):')
print(df['living_alone_flag'].value_counts())
print()
print('Percentage:')
print((df['living_alone_flag'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: 0: 74%, 1: 23%, Unknown: 3%')

# %% [markdown]
# ### med_adherence_pdc — Expected: <0.5: 10%, 0.5-0.79: 30%, >=0.80: 60%

# %%
# med_adherence_pdc — Expected: <0.5: 10%, 0.5-0.79: 30%, >=0.80: 60%
bucketed = pd.cut(df['med_adherence_pdc'], bins=[-0.01, 0.5, 0.79, 1.01], labels=['<0.5', '0.5-0.79', '>=0.80'], right=False)
print('med_adherence_pdc bucketed value counts:')
print(bucketed.value_counts().reindex(['<0.5', '0.5-0.79', '>=0.80']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['<0.5', '0.5-0.79', '>=0.80']) * 100).round(1))
print('\nExpected: <0.5: 10%, 0.5-0.79: 30%, >=0.80: 60%')

# %% [markdown]
# ### observation_stays_last_6m — Expected: 0: 91%, 1: 6%, 2: 2%, 3+: 1%

# %%
# observation_stays_last_6m — Expected: 0: 91%, 1: 6%, 2: 2%, 3+: 1%
bucketed = df['observation_stays_last_6m'].clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'})
print('observation_stays_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(['0', '1', '2', '3+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['0', '1', '2', '3+']) * 100).round(1))
print('\nExpected: 0: 91%, 1: 6%, 2: 2%, 3+: 1%')

# %% [markdown]
# ### pcp_visits_last_6m — Expected: 0: 15%, 1-2: 30%, 3-5: 35%, 6+: 20%

# %%
# pcp_visits_last_6m — Expected: 0: 15%, 1-2: 30%, 3-5: 35%, 6+: 20%
bucketed = pd.cut(df['pcp_visits_last_6m'], bins=[-1, 0, 2, 5, 9999], labels=['0', '1-2', '3-5', '6+'])
print('pcp_visits_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(['0', '1-2', '3-5', '6+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['0', '1-2', '3-5', '6+']) * 100).round(1))
print('\nExpected: 0: 15%, 1-2: 30%, 3-5: 35%, 6+: 20%')

# %% [markdown]
# ### rx_count_last_6m — Expected: 0: 10%, 1-2: 12%, 3-5: 18%, 6-11: 25%, 12-23: 22%, 24-35: 8%, 36+: 5%

# %%
# rx_count_last_6m — Expected: 0: 10%, 1-2: 12%, 3-5: 18%, 6-11: 25%, 12-23: 22%, 24-35: 8%, 36+: 5%
bucketed = pd.cut(df['rx_count_last_6m'], bins=[-1, 0, 2, 5, 11, 23, 35, 9999], labels=['0', '1-2', '3-5', '6-11', '12-23', '24-35', '36+'])
order = ['0', '1-2', '3-5', '6-11', '12-23', '24-35', '36+']
print('rx_count_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(order))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(order) * 100).round(1))
print('\nExpected: 0: 10%, 1-2: 12%, 3-5: 18%, 6-11: 25%, 12-23: 22%, 24-35: 8%, 36+: 5%')

# %% [markdown]
# ### specialist_visits_last_6m — Expected: 0: 30%, 1-2: 30%, 3-5: 25%, 6+: 15%

# %%
# specialist_visits_last_6m — Expected: 0: 30%, 1-2: 30%, 3-5: 25%, 6+: 15%
bucketed = pd.cut(df['specialist_visits_last_6m'], bins=[-1, 0, 2, 5, 9999], labels=['0', '1-2', '3-5', '6+'])
print('specialist_visits_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(['0', '1-2', '3-5', '6+']))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(['0', '1-2', '3-5', '6+']) * 100).round(1))
print('\nExpected: 0: 30%, 1-2: 30%, 3-5: 25%, 6+: 15%')

# %% [markdown]
# ### total_cost_last_6m — Expected: $0-499: 10%, $500-1999: 20%, $2000-4999: 25%, $5000-9999: 20%, $10000-24999: 15%, $25000-49999: 7%, $50000+: 3%

# %%
# total_cost_last_6m — Expected: $0-499: 10%, $500-1999: 20%, $2000-4999: 25%, $5000-9999: 20%, $10000-24999: 15%, $25000-49999: 7%, $50000+: 3%
bucketed = pd.cut(df['total_cost_last_6m'], bins=[-1, 499, 1999, 4999, 9999, 24999, 49999, 999999999],
                  labels=['$0-499', '$500-1999', '$2000-4999', '$5000-9999', '$10000-24999', '$25000-49999', '$50000+'])
order = ['$0-499', '$500-1999', '$2000-4999', '$5000-9999', '$10000-24999', '$25000-49999', '$50000+']
print('total_cost_last_6m bucketed value counts:')
print(bucketed.value_counts().reindex(order))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(order) * 100).round(1))
print('\nExpected: $0-499: 10%, $500-1999: 20%, $2000-4999: 25%, $5000-9999: 20%, $10000-24999: 15%, $25000-49999: 7%, $50000+: 3%')

# %% [markdown]
# ---
# ## Score Variables (0-100 range)
# Bucketed into 0-19, 20-39, 40-59, 60-79, 80-100.

# %% [markdown]
# ### current_risk_score — Expected: 0-19: 8%, 20-39: 22%, 40-59: 35%, 60-79: 25%, 80-100: 10%

# %%
# current_risk_score — Expected: 0-19: 8%, 20-39: 22%, 40-59: 35%, 60-79: 25%, 80-100: 10%
bucketed = pd.cut(df['current_risk_score'], bins=[-1, 19, 39, 59, 79, 100], labels=['0-19', '20-39', '40-59', '60-79', '80-100'])
order = ['0-19', '20-39', '40-59', '60-79', '80-100']
print('current_risk_score bucketed value counts:')
print(bucketed.value_counts().reindex(order))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(order) * 100).round(1))
print('\nExpected: 0-19: 8%, 20-39: 22%, 40-59: 35%, 60-79: 25%, 80-100: 10%')

# %% [markdown]
# ### percolator_clinical_score — Expected: 0-19: 12%, 20-39: 28%, 40-59: 30%, 60-79: 20%, 80-100: 10%

# %%
# percolator_clinical_score — Expected: 0-19: 12%, 20-39: 28%, 40-59: 30%, 60-79: 20%, 80-100: 10%
bucketed = pd.cut(df['percolator_clinical_score'], bins=[-1, 19, 39, 59, 79, 100], labels=['0-19', '20-39', '40-59', '60-79', '80-100'])
order = ['0-19', '20-39', '40-59', '60-79', '80-100']
print('percolator_clinical_score bucketed value counts:')
print(bucketed.value_counts().reindex(order))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(order) * 100).round(1))
print('\nExpected: 0-19: 12%, 20-39: 28%, 40-59: 30%, 60-79: 20%, 80-100: 10%')

# %% [markdown]
# ### percolator_sdoh_score — Expected: 0-19: 35%, 20-39: 25%, 40-59: 20%, 60-79: 12%, 80-100: 8%

# %%
# percolator_sdoh_score — Expected: 0-19: 35%, 20-39: 25%, 40-59: 20%, 60-79: 12%, 80-100: 8%
bucketed = pd.cut(df['percolator_sdoh_score'], bins=[-1, 19, 39, 59, 79, 100], labels=['0-19', '20-39', '40-59', '60-79', '80-100'])
order = ['0-19', '20-39', '40-59', '60-79', '80-100']
print('percolator_sdoh_score bucketed value counts:')
print(bucketed.value_counts().reindex(order))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(order) * 100).round(1))
print('\nExpected: 0-19: 35%, 20-39: 25%, 40-59: 20%, 60-79: 12%, 80-100: 8%')

# %% [markdown]
# ### percolator_utilization_score — Expected: 0-19: 35%, 20-39: 30%, 40-59: 18%, 60-79: 10%, 80-100: 7%

# %%
# percolator_utilization_score — Expected: 0-19: 35%, 20-39: 30%, 40-59: 18%, 60-79: 10%, 80-100: 7%
bucketed = pd.cut(df['percolator_utilization_score'], bins=[-1, 19, 39, 59, 79, 100], labels=['0-19', '20-39', '40-59', '60-79', '80-100'])
order = ['0-19', '20-39', '40-59', '60-79', '80-100']
print('percolator_utilization_score bucketed value counts:')
print(bucketed.value_counts().reindex(order))
print()
print('Percentage:')
print((bucketed.value_counts(normalize=True).reindex(order) * 100).round(1))
print('\nExpected: 0-19: 35%, 20-39: 30%, 40-59: 18%, 60-79: 10%, 80-100: 7%')

# %% [markdown]
# ---
# ## Categorical Variables
# Each cell shows value_counts (raw + percentage) for top categories.

# %% [markdown]
# ### case_manager_name — Expected: ~4-5 managers at 20-24% each

# %%
# case_manager_name — Expected: ~4-5 managers at 20-24% each
print('case_manager_name value counts:')
print(df['case_manager_name'].value_counts())
print()
print('Percentage:')
print((df['case_manager_name'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: ~4-5 managers at 20-24% each')

# %% [markdown]
# ### client_contract — Expected: Medicaid MCO: 40%, Medicaid Expansion: 18%, Dual Eligibility: 22%, MLTSS: 8%, etc.

# %%
# client_contract — Expected: Medicaid MCO: 40%, Medicaid Expansion: 18%, Dual Eligibility: 22%, MLTSS: 8%
print('client_contract value counts:')
print(df['client_contract'].value_counts())
print()
print('Percentage:')
print((df['client_contract'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Medicaid MCO: 40%, Medicaid Expansion: 18%, Dual Eligibility: 22%, MLTSS: 8%, Behavioral Health: 6%, Health Home: 3%, Maternal Health: 2%, SUD: 1%')

# %% [markdown]
# ### county — Expected: descending shares from ~28% down

# %%
# county — Expected: descending shares from ~28% down
print('county value counts:')
print(df['county'].value_counts())
print()
print('Percentage:')
print((df['county'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Top county ~28%, descending from there')

# %% [markdown]
# ### gender — Expected: Female: 56%, Male: 43%

# %%
# gender — Expected: Female: 56%, Male: 43%
print('gender value counts:')
print(df['gender'].value_counts())
print()
print('Percentage:')
print((df['gender'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Female: 56%, Male: 43%')

# %% [markdown]
# ### language — Expected: English: 78%, Spanish: 13%

# %%
# language — Expected: English: 78%, Spanish: 13%
print('language value counts:')
print(df['language'].value_counts())
print()
print('Percentage:')
print((df['language'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: English: 78%, Spanish: 13%')

# %% [markdown]
# ### plan_type — Expected: Comprehensive_MCO: 70%, MLTSS: 8%, D-SNP: 7%

# %%
# plan_type — Expected: Comprehensive_MCO: 70%, MLTSS: 8%, D-SNP: 7%
print('plan_type value counts:')
print(df['plan_type'].value_counts())
print()
print('Percentage:')
print((df['plan_type'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Comprehensive_MCO: 70%, MLTSS: 8%, D-SNP: 7%')

# %% [markdown]
# ### program — Expected: Complex Care Management: 30%, High_Risk Case Management: 20%, Behavioral Health Integration: 14%, Health Home: 10%, LTSS: 8%

# %%
# program — Expected: Complex Care Management: 30%, High_Risk Case Management: 20%, Behavioral Health Integration: 14%, Health Home: 10%, LTSS: 8%
print('program value counts:')
print(df['program'].value_counts())
print()
print('Percentage:')
print((df['program'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Complex Care Management: 30%, High_Risk Case Management: 20%, Behavioral Health Integration: 14%, Health Home: 10%, LTSS: 8%')

# %% [markdown]
# ### risk_tier — Expected: Low: 25%, Moderate: 35%, High: 25%, Very High: 10%

# %%
# risk_tier — Expected: Low: 25%, Moderate: 35%, High: 25%, Very High: 10%
print('risk_tier value counts:')
print(df['risk_tier'].value_counts())
print()
print('Percentage:')
print((df['risk_tier'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Low: 25%, Moderate: 35%, High: 25%, Very High: 10%, Rising Risk: 3%, Impactable High Risk: 2%')

# %% [markdown]
# ### service_region — Expected: Urban Core: 45%, Suburban: 25%, Rural: 20%, Frontier: 5%

# %%
# service_region — Expected: Urban Core: 45%, Suburban: 25%, Rural: 20%, Frontier: 5%
print('service_region value counts:')
print(df['service_region'].value_counts())
print()
print('Percentage:')
print((df['service_region'].value_counts(normalize=True) * 100).round(1))
print('\nExpected: Urban Core: 45%, Suburban: 25%, Rural: 20%, Frontier: 5%')

# %% [markdown]
# ---
# ## Helper Functions & Automated Validation

# %%
def check_binary_flag(col, low, high):
    """Check binary flag proportion against expected range."""
    if col not in df.columns:
        return {'Variable': col, 'Expected_Distribution': f'{low*100:.1f}%-{high*100:.1f}%',
                'Observed_Distribution': 'COLUMN NOT FOUND', 'Max_Bucket_Diff': None,
                'Avg_Bucket_Diff': None, 'KD_Result': 'FAIL - Missing Column'}
    obs_pct = df[col].mean()
    passed = low <= obs_pct <= high
    diff = 0 if passed else min(abs(obs_pct - low), abs(obs_pct - high))
    return {'Variable': col, 'Expected_Distribution': f'{low*100:.1f}%-{high*100:.1f}% of 1s',
            'Observed_Distribution': f'{obs_pct*100:.1f}% of 1s',
            'Max_Bucket_Diff': round(diff * 100, 2),
            'Avg_Bucket_Diff': round(diff * 100, 2),
            'KD_Result': 'PASS' if passed else 'FAIL'}

def check_bucketed(col, buckets, bucket_fn, expected_pcts):
    """Check bucketed distribution against expected percentages."""
    if col not in df.columns:
        return {'Variable': col, 'Expected_Distribution': str(dict(zip(buckets, expected_pcts))),
                'Observed_Distribution': 'COLUMN NOT FOUND', 'Max_Bucket_Diff': None,
                'Avg_Bucket_Diff': None, 'KD_Result': 'FAIL - Missing Column'}
    bucketed = bucket_fn(df[col])
    obs_counts = bucketed.value_counts(normalize=True)
    obs_pcts = [obs_counts.get(b, 0) * 100 for b in buckets]
    diffs = [abs(o - e) for o, e in zip(obs_pcts, expected_pcts)]
    max_diff = max(diffs)
    avg_diff = sum(diffs) / len(diffs)
    passed = max_diff <= 10.0
    exp_str = ', '.join([f'{b}: {e:.0f}%' for b, e in zip(buckets, expected_pcts)])
    obs_str = ', '.join([f'{b}: {o:.1f}%' for b, o in zip(buckets, obs_pcts)])
    return {'Variable': col, 'Expected_Distribution': exp_str,
            'Observed_Distribution': obs_str,
            'Max_Bucket_Diff': round(max_diff, 2),
            'Avg_Bucket_Diff': round(avg_diff, 2),
            'KD_Result': 'PASS' if passed else 'FAIL'}

def check_categorical(col, expected_dict, tolerance=10.0):
    """Check categorical distribution against expected percentages."""
    if col not in df.columns:
        return {'Variable': col, 'Expected_Distribution': str(expected_dict),
                'Observed_Distribution': 'COLUMN NOT FOUND', 'Max_Bucket_Diff': None,
                'Avg_Bucket_Diff': None, 'KD_Result': 'FAIL - Missing Column'}
    obs_counts = df[col].value_counts(normalize=True) * 100
    diffs = [abs(obs_counts.get(cat, 0) - exp) for cat, exp in expected_dict.items()]
    max_diff = max(diffs) if diffs else 0
    avg_diff = sum(diffs) / len(diffs) if diffs else 0
    passed = max_diff <= tolerance
    exp_str = ', '.join([f'{k}: {v:.0f}%' for k, v in expected_dict.items()])
    obs_str = ', '.join([f'{k}: {v:.1f}%' for k, v in obs_counts.head(10).items()])
    return {'Variable': col, 'Expected_Distribution': exp_str,
            'Observed_Distribution': obs_str,
            'Max_Bucket_Diff': round(max_diff, 2),
            'Avg_Bucket_Diff': round(avg_diff, 2),
            'KD_Result': 'PASS' if passed else 'FAIL'}

# %% [markdown]
# ## Build Summary Results & Export to Excel

# %%
# --- Binary Flags ---
results.append(check_binary_flag('anxiety_flag', 0.18, 0.28))
results.append(check_binary_flag('asthma_flag', 0.12, 0.18))
results.append(check_binary_flag('behavioral_health_risk_flag', 0.20, 0.30))
results.append(check_binary_flag('chf_flag', 0.115, 0.165))
results.append(check_binary_flag('ckd_flag', 0.125, 0.175))
results.append(check_binary_flag('copd_flag', 0.085, 0.135))
results.append(check_binary_flag('depression_flag', 0.20, 0.30))
results.append(check_binary_flag('diabetes_flag', 0.255, 0.305))
results.append(check_binary_flag('dual_eligible', 0.18, 0.25))
results.append(check_binary_flag('food_insecurity_flag', 0.15, 0.25))
results.append(check_binary_flag('high_cost_drug_flag', 0.05, 0.10))
results.append(check_binary_flag('housing_instability_flag', 0.08, 0.15))
results.append(check_binary_flag('opioid_flag', 0.05, 0.10))
results.append(check_binary_flag('polypharmacy_flag', 0.15, 0.25))
results.append(check_binary_flag('pregnancy_flag', 0.03, 0.06))
results.append(check_binary_flag('substance_use_flag', 0.08, 0.15))
results.append(check_binary_flag('transportation_barrier_flag', 0.12, 0.20))
results.append(check_binary_flag('utilities_insecurity_flag', 0.095, 0.145))

# --- Bucketed Numeric ---
results.append(check_bucketed('admits_last_6m', ['0', '1', '2', '3+'],
    lambda s: s.clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'}), [85, 10, 3, 2]))
results.append(check_bucketed('age', ['18-34', '35-49', '50-64', '65+'],
    lambda s: pd.cut(s, bins=[17, 34, 49, 64, 200], labels=['18-34', '35-49', '50-64', '65+']), [20, 25, 35, 20]))
results.append(check_bucketed('ed_visits_last_30d', ['0', '1', '2', '3+'],
    lambda s: s.clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'}), [92, 6, 1.5, 0.5]))
results.append(check_bucketed('ed_visits_last_6m', ['0', '1', '2', '3+'],
    lambda s: s.clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'}), [70, 15, 8, 7]))
results.append(check_bucketed('living_alone_flag', ['0', '1', 'Unknown/Missing'],
    lambda s: s.astype(str).map(lambda x: '0' if x in ('0','0.0') else ('1' if x in ('1','1.0') else 'Unknown/Missing')), [74, 23, 3]))
results.append(check_bucketed('med_adherence_pdc', ['<0.5', '0.5-0.79', '>=0.80'],
    lambda s: pd.cut(s, bins=[-0.01, 0.5, 0.79, 1.01], labels=['<0.5', '0.5-0.79', '>=0.80'], right=False), [10, 30, 60]))
results.append(check_bucketed('observation_stays_last_6m', ['0', '1', '2', '3+'],
    lambda s: s.clip(upper=3).map({0: '0', 1: '1', 2: '2', 3: '3+'}), [91, 6, 2, 1]))
results.append(check_bucketed('pcp_visits_last_6m', ['0', '1-2', '3-5', '6+'],
    lambda s: pd.cut(s, bins=[-1, 0, 2, 5, 9999], labels=['0', '1-2', '3-5', '6+']), [15, 30, 35, 20]))
results.append(check_bucketed('rx_count_last_6m', ['0', '1-2', '3-5', '6-11', '12-23', '24-35', '36+'],
    lambda s: pd.cut(s, bins=[-1, 0, 2, 5, 11, 23, 35, 9999], labels=['0', '1-2', '3-5', '6-11', '12-23', '24-35', '36+']), [10, 12, 18, 25, 22, 8, 5]))
results.append(check_bucketed('specialist_visits_last_6m', ['0', '1-2', '3-5', '6+'],
    lambda s: pd.cut(s, bins=[-1, 0, 2, 5, 9999], labels=['0', '1-2', '3-5', '6+']), [30, 30, 25, 15]))
results.append(check_bucketed('total_cost_last_6m', ['$0-499', '$500-1999', '$2000-4999', '$5000-9999', '$10000-24999', '$25000-49999', '$50000+'],
    lambda s: pd.cut(s, bins=[-1, 499, 1999, 4999, 9999, 24999, 49999, 999999999],
                     labels=['$0-499', '$500-1999', '$2000-4999', '$5000-9999', '$10000-24999', '$25000-49999', '$50000+']), [10, 20, 25, 20, 15, 7, 3]))

# --- Scores ---
def bucket_score(s):
    return pd.cut(s, bins=[-1, 19, 39, 59, 79, 100], labels=['0-19', '20-39', '40-59', '60-79', '80-100'])

results.append(check_bucketed('current_risk_score', ['0-19', '20-39', '40-59', '60-79', '80-100'], bucket_score, [8, 22, 35, 25, 10]))
results.append(check_bucketed('percolator_clinical_score', ['0-19', '20-39', '40-59', '60-79', '80-100'], bucket_score, [12, 28, 30, 20, 10]))
results.append(check_bucketed('percolator_sdoh_score', ['0-19', '20-39', '40-59', '60-79', '80-100'], bucket_score, [35, 25, 20, 12, 8]))
results.append(check_bucketed('percolator_utilization_score', ['0-19', '20-39', '40-59', '60-79', '80-100'], bucket_score, [35, 30, 18, 10, 7]))

# %%
# --- Categorical ---
# case_manager_name
obs_cm = df['case_manager_name'].value_counts(normalize=True) * 100
top_val = obs_cm.iloc[0]
n_cats = len(obs_cm)
passed_cm = (top_val <= 30) and (n_cats >= 4)
max_diff_cm = max(0, top_val - 24)
obs_str_cm = ', '.join([f'{k}: {v:.1f}%' for k, v in obs_cm.head(6).items()])
results.append({'Variable': 'case_manager_name',
    'Expected_Distribution': '~4-5 managers at 20-24% each, ~5% unassigned',
    'Observed_Distribution': obs_str_cm,
    'Max_Bucket_Diff': round(max_diff_cm, 2),
    'Avg_Bucket_Diff': round(max_diff_cm / 2, 2),
    'KD_Result': 'PASS' if passed_cm else 'FAIL'})

results.append(check_categorical('client_contract', {
    'Medicaid MCO': 40, 'Medicaid Expansion': 18, 'Dual Eligibility': 22,
    'MLTSS': 8, 'Behavioral Health': 6, 'Health Home': 3,
    'Maternal Health': 2, 'SUD': 1}))

# county
obs_county = df['county'].value_counts(normalize=True) * 100
top_county = obs_county.iloc[0]
n_counties = len(obs_county)
passed_cty = (18 <= top_county <= 38) and (n_counties >= 8)
max_diff_cty = abs(top_county - 28)
obs_str_cty = ', '.join([f'{k}: {v:.1f}%' for k, v in obs_county.head(10).items()])
results.append({'Variable': 'county',
    'Expected_Distribution': 'Top: 28%, 18%, 14%, 10%, 8%, 6%, 5%, 4%, 2%, 5% unknown',
    'Observed_Distribution': obs_str_cty,
    'Max_Bucket_Diff': round(max_diff_cty, 2),
    'Avg_Bucket_Diff': round(max_diff_cty / 2, 2),
    'KD_Result': 'PASS' if passed_cty else 'FAIL'})

results.append(check_categorical('gender', {'Female': 56, 'Male': 43}, tolerance=10.0))
results.append(check_categorical('language', {'English': 78, 'Spanish': 13}, tolerance=10.0))
results.append(check_categorical('plan_type', {'Comprehensive_MCO': 70, 'MLTSS': 8, 'D-SNP': 7}, tolerance=10.0))
results.append(check_categorical('program', {
    'Complex Care Management': 30, 'High_Risk Case Management': 20,
    'Behavioral Health Integration': 14, 'Health Home': 10, 'LTSS': 8}, tolerance=10.0))
results.append(check_categorical('risk_tier', {
    'Low': 25, 'Moderate': 35, 'High': 25, 'Very High': 10,
    'Rising Risk': 3, 'Impactable High Risk': 2}, tolerance=10.0))
results.append(check_categorical('service_region', {
    'Urban Core': 45, 'Suburban': 25, 'Rural': 20, 'Frontier': 5}, tolerance=10.0))

print(f'Total results collected: {len(results)}')

# %% [markdown]
# ## Summary & Export

# %%
summary_df = pd.DataFrame(results)
print(f'Total variables checked: {len(summary_df)}')
print(f'PASS: {(summary_df["KD_Result"] == "PASS").sum()}')
print(f'FAIL: {(summary_df["KD_Result"] != "PASS").sum()}')
print()
print(summary_df[['Variable', 'Max_Bucket_Diff', 'KD_Result']].to_string(index=False))

# Export to Excel
summary_df.to_excel('distribution_validation_results.xlsx', index=False, sheet_name='Distribution Validation')
print(f'\nResults exported to: distribution_validation_results.xlsx')

# %% [markdown]
# ## Full Results Table (Styled)

# %%
summary_df.style.applymap(
    lambda v: 'background-color: #d4edda' if v == 'PASS' else ('background-color: #f8d7da' if v == 'FAIL' else ''),
    subset=['KD_Result'])
