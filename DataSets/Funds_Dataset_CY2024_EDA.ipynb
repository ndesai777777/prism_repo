# %% [markdown]
# # Funds Dataset CY2024 — Exploratory Data Analysis
#
# Comprehensive variable-by-variable EDA for `Funds_Dataset_CY2024.csv`.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Funds_Dataset_CY2024.csv')
print(f'Shape: {df.shape}')
print(f'\nColumns ({len(df.columns)}):')
print(list(df.columns))
# Out:
# Shape: (51688, 56)
#
# Columns (56):
# ['member_id', 'client_contract', 'age', 'gender', 'dual_elg', 'date_of_death', 'County', 'State', 'plan_type', 'diabetes_flag', 'chf_flag', 'copd_flag', 'asthma_flag', 'depression_flag', 'anxiety_flag', 'substance_use_flag', 'ckd_flag', 'bh_flag', 'htn_flag', 'hyperlipidemia_flag', 'cad_flag', 'financial_strain_flag', 'food_insecurity_flag', 'housing_instability_flag', 'transportation_barrier_flag', 'healthliteracy_challenges_flag', 'op_visits_last_6m', 'ed_visits_last_30d', 'ed_visits_last_6m', 'admits_last_6m', 'observation_stays_last_6m', 'total_cost_last_6m', 'rx_count_last_6m', 'opioid_flag', 'polypharmacy_flag', 'current_risk_score', 'percolator_score', 'risk_tier', 'program', 'Engaged_flag', 'OptOut_flag', 'ProgramStart', 'ProgramEnd', 'engaged_date', 'engagement_length', 'case_manager_name', 'InterventionCount', 'SuccessfulInterventions', 'outcome_ed_30d', 'outcome_ed_90d', 'outcome_ed_6MO', 'outcome_admit_30d', 'outcome_admit_90d', 'outcome_admit_6MO', 'outcome_total_cost_90d', 'outcome_total_cost_6MO']

# %% [markdown]
# ---
# ## Numeric Variables

# %% [markdown]
# ### age

# %%
col = 'age'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === age ===
# Count: 51688
# Missing: 0 (0.0%)
# count    51688.000000
# mean        68.513182
# std         18.593426
# min         -0.837782
# 25%         66.811772
# 50%         72.698151
# 75%         78.403832
# max        107.074606
# Name: age, dtype: float64

# %% [markdown]
# ### op_visits_last_6m

# %%
col = 'op_visits_last_6m'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === op_visits_last_6m ===
# Count: 44550
# Missing: 7138 (13.8%)
# count    44550.000000
# mean         4.908934
# std          3.741206
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          7.000000
# max        132.000000
# Name: op_visits_last_6m, dtype: float64

# %% [markdown]
# ### ed_visits_last_30d

# %%
col = 'ed_visits_last_30d'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === ed_visits_last_30d ===
# Count: 2718
# Missing: 48970 (94.7%)
# count    2718.000000
# mean        1.189478
# std         0.496369
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         8.000000
# Name: ed_visits_last_30d, dtype: float64

# %% [markdown]
# ### ed_visits_last_6m

# %%
col = 'ed_visits_last_6m'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === ed_visits_last_6m ===
# Count: 10711
# Missing: 40977 (79.3%)
# count    10711.000000
# mean         1.634114
# std          1.226348
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         30.000000
# Name: ed_visits_last_6m, dtype: float64

# %% [markdown]
# ### admits_last_6m

# %%
col = 'admits_last_6m'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === admits_last_6m ===
# Count: 5436
# Missing: 46252 (89.5%)
# count    5436.000000
# mean        1.400846
# std         0.844219
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        14.000000
# Name: admits_last_6m, dtype: float64

# %% [markdown]
# ### observation_stays_last_6m

# %%
col = 'observation_stays_last_6m'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === observation_stays_last_6m ===
# Count: 2025
# Missing: 49663 (96.1%)
# count    2025.000000
# mean        1.261235
# std         0.627439
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         8.000000
# Name: observation_stays_last_6m, dtype: float64

# %% [markdown]
# ### total_cost_last_6m

# %%
col = 'total_cost_last_6m'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === total_cost_last_6m ===
# Count: 45670
# Missing: 6018 (11.6%)
# count    4.567000e+04
# mean     1.332633e+04
# std      2.558961e+04
# min     -2.476265e+04
# 25%      2.078445e+03
# 50%      6.883065e+03
# 75%      1.609302e+04
# max      1.527817e+06
# Name: total_cost_last_6m, dtype: float64

# %% [markdown]
# ### rx_count_last_6m

# %%
col = 'rx_count_last_6m'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === rx_count_last_6m ===
# Count: 46517
# Missing: 5171 (10.0%)
# count    46517.000000
# mean        22.591289
# std         19.802482
# min          1.000000
# 25%          9.000000
# 50%         18.000000
# 75%         30.000000
# max        323.000000
# Name: rx_count_last_6m, dtype: float64

# %% [markdown]
# ### current_risk_score

# %%
col = 'current_risk_score'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === current_risk_score ===
# Count: 47002
# Missing: 4686 (9.1%)
# count    47002.000000
# mean         3.873274
# std          3.195314
# min          0.182822
# 25%          1.745391
# 50%          2.931875
# 75%          4.929545
# max         43.938487
# Name: current_risk_score, dtype: float64

# %% [markdown]
# ### percolator_score

# %%
col = 'percolator_score'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === percolator_score ===
# Count: 47002
# Missing: 4686 (9.1%)
# count    47002.000000
# mean       428.715803
# std        413.821414
# min          8.121200
# 25%        130.387140
# 50%        265.360620
# 75%        576.071390
# max       3912.012480
# Name: percolator_score, dtype: float64

# %% [markdown]
# ### engagement_length

# %%
col = 'engagement_length'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === engagement_length ===
# Count: 1024
# Missing: 50664 (98.0%)
# count    1024.000000
# mean      192.490234
# std        60.703516
# min         0.000000
# 25%       168.000000
# 50%       183.500000
# 75%       215.000000
# max       405.000000
# Name: engagement_length, dtype: float64

# %% [markdown]
# ### InterventionCount

# %%
col = 'InterventionCount'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === InterventionCount ===
# Count: 3915
# Missing: 47773 (92.4%)
# count    3915.000000
# mean       10.294253
# std         8.090871
# min         0.000000
# 25%         5.000000
# 50%         9.000000
# 75%        14.000000
# max        71.000000
# Name: InterventionCount, dtype: float64

# %% [markdown]
# ### SuccessfulInterventions

# %%
col = 'SuccessfulInterventions'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === SuccessfulInterventions ===
# Count: 3915
# Missing: 47773 (92.4%)
# count    3915.000000
# mean        9.150192
# std         8.083268
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        13.000000
# max        71.000000
# Name: SuccessfulInterventions, dtype: float64

# %% [markdown]
# ### outcome_ed_30d

# %%
col = 'outcome_ed_30d'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_ed_30d ===
# Count: 295
# Missing: 51393 (99.4%)
# count    295.000000
# mean       1.267797
# std        0.638461
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        7.000000
# Name: outcome_ed_30d, dtype: float64

# %% [markdown]
# ### outcome_ed_90d

# %%
col = 'outcome_ed_90d'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_ed_90d ===
# Count: 620
# Missing: 51068 (98.8%)
# count    620.000000
# mean       1.595161
# std        1.098821
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       14.000000
# Name: outcome_ed_90d, dtype: float64

# %% [markdown]
# ### outcome_ed_6MO

# %%
col = 'outcome_ed_6MO'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_ed_6MO ===
# Count: 904
# Missing: 50784 (98.3%)
# count    904.000000
# mean       2.119469
# std        1.776897
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       16.000000
# Name: outcome_ed_6MO, dtype: float64

# %% [markdown]
# ### outcome_admit_30d

# %%
col = 'outcome_admit_30d'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_admit_30d ===
# Count: 315
# Missing: 51373 (99.4%)
# count    315.000000
# mean       1.139683
# std        0.365093
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: outcome_admit_30d, dtype: float64

# %% [markdown]
# ### outcome_admit_90d

# %%
col = 'outcome_admit_90d'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_admit_90d ===
# Count: 518
# Missing: 51170 (99.0%)
# count    518.000000
# mean       1.357143
# std        0.721229
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        6.000000
# Name: outcome_admit_90d, dtype: float64

# %% [markdown]
# ### outcome_admit_6MO

# %%
col = 'outcome_admit_6MO'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_admit_6MO ===
# Count: 727
# Missing: 50961 (98.6%)
# count    727.00000
# mean       1.65337
# std        1.14911
# min        1.00000
# 25%        1.00000
# 50%        1.00000
# 75%        2.00000
# max       13.00000
# Name: outcome_admit_6MO, dtype: float64

# %% [markdown]
# ### outcome_total_cost_90d

# %%
col = 'outcome_total_cost_90d'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_total_cost_90d ===
# Count: 2231
# Missing: 49457 (95.7%)
# count      2231.000000
# mean       8054.708785
# std       16651.231268
# min       -1212.950000
# 25%        1993.185000
# 50%        4351.810000
# 75%        8502.075000
# max      529392.690000
# Name: outcome_total_cost_90d, dtype: float64

# %% [markdown]
# ### outcome_total_cost_6MO

# %%
col = 'outcome_total_cost_6MO'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Count: {df[col].notna().sum()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print(df[col].describe())
plt.figure(figsize=(8, 3.5))
df[col].dropna().hist(bins=30, edgecolor='white')
plt.title(f'{col} distribution')
plt.xlabel(col)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === outcome_total_cost_6MO ===
# Count: 2232
# Missing: 49456 (95.7%)
# count      2232.000000
# mean      15613.983297
# std       25409.783637
# min        -807.860000
# 25%        4224.452500
# 50%        9044.710000
# 75%       17153.507500
# max      612804.710000
# Name: outcome_total_cost_6MO, dtype: float64

# %% [markdown]
# ---
# ## Binary / Indicator Variables

# %% [markdown]
# ### diabetes_flag

# %%
col = 'diabetes_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === diabetes_flag ===
# Missing: 0 (0.0%)
# diabetes_flag
# 0    36701
# 1    14987
# Name: count, dtype: int64
#
# Rate of 1/Yes: 29.0%

# %% [markdown]
# ### chf_flag

# %%
col = 'chf_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === chf_flag ===
# Missing: 0 (0.0%)
# chf_flag
# 0    45866
# 1     5822
# Name: count, dtype: int64
#
# Rate of 1/Yes: 11.3%

# %% [markdown]
# ### copd_flag

# %%
col = 'copd_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === copd_flag ===
# Missing: 0 (0.0%)
# copd_flag
# 0    42812
# 1     8876
# Name: count, dtype: int64
#
# Rate of 1/Yes: 17.2%

# %% [markdown]
# ### asthma_flag

# %%
col = 'asthma_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === asthma_flag ===
# Missing: 0 (0.0%)
# asthma_flag
# 0    49390
# 1     2298
# Name: count, dtype: int64
#
# Rate of 1/Yes: 4.4%

# %% [markdown]
# ### depression_flag

# %%
col = 'depression_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === depression_flag ===
# Missing: 0 (0.0%)
# depression_flag
# 0    47870
# 1     3818
# Name: count, dtype: int64
#
# Rate of 1/Yes: 7.4%

# %% [markdown]
# ### anxiety_flag

# %%
col = 'anxiety_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === anxiety_flag ===
# Missing: 0 (0.0%)
# anxiety_flag
# 0    44076
# 1     7612
# Name: count, dtype: int64
#
# Rate of 1/Yes: 14.7%

# %% [markdown]
# ### substance_use_flag

# %%
col = 'substance_use_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === substance_use_flag ===
# Missing: 0 (0.0%)
# substance_use_flag
# 0    50804
# 1      884
# Name: count, dtype: int64
#
# Rate of 1/Yes: 1.7%

# %% [markdown]
# ### ckd_flag

# %%
col = 'ckd_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === ckd_flag ===
# Missing: 0 (0.0%)
# ckd_flag
# 0    44519
# 1     7169
# Name: count, dtype: int64
#
# Rate of 1/Yes: 13.9%

# %% [markdown]
# ### bh_flag

# %%
col = 'bh_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === bh_flag ===
# Missing: 0 (0.0%)
# bh_flag
# 0    42155
# 1     9533
# Name: count, dtype: int64
#
# Rate of 1/Yes: 18.4%

# %% [markdown]
# ### htn_flag

# %%
col = 'htn_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === htn_flag ===
# Missing: 0 (0.0%)
# htn_flag
# 1    32133
# 0    19555
# Name: count, dtype: int64
#
# Rate of 1/Yes: 62.2%

# %% [markdown]
# ### hyperlipidemia_flag

# %%
col = 'hyperlipidemia_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === hyperlipidemia_flag ===
# Missing: 0 (0.0%)
# hyperlipidemia_flag
# 1    25847
# 0    25841
# Name: count, dtype: int64
#
# Rate of 1/Yes: 50.0%

# %% [markdown]
# ### cad_flag

# %%
col = 'cad_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === cad_flag ===
# Missing: 0 (0.0%)
# cad_flag
# 0    40284
# 1    11404
# Name: count, dtype: int64
#
# Rate of 1/Yes: 22.1%

# %% [markdown]
# ### financial_strain_flag

# %%
col = 'financial_strain_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === financial_strain_flag ===
# Missing: 0 (0.0%)
# financial_strain_flag
# 0    38997
# 1    12691
# Name: count, dtype: int64
#
# Rate of 1/Yes: 24.6%

# %% [markdown]
# ### food_insecurity_flag

# %%
col = 'food_insecurity_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === food_insecurity_flag ===
# Missing: 0 (0.0%)
# food_insecurity_flag
# 0    39076
# 1    12612
# Name: count, dtype: int64
#
# Rate of 1/Yes: 24.4%

# %% [markdown]
# ### housing_instability_flag

# %%
col = 'housing_instability_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === housing_instability_flag ===
# Missing: 0 (0.0%)
# housing_instability_flag
# 0    39040
# 1    12648
# Name: count, dtype: int64
#
# Rate of 1/Yes: 24.5%

# %% [markdown]
# ### transportation_barrier_flag

# %%
col = 'transportation_barrier_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === transportation_barrier_flag ===
# Missing: 0 (0.0%)
# transportation_barrier_flag
# 0    40084
# 1    11604
# Name: count, dtype: int64
#
# Rate of 1/Yes: 22.5%

# %% [markdown]
# ### healthliteracy_challenges_flag

# %%
col = 'healthliteracy_challenges_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === healthliteracy_challenges_flag ===
# Missing: 0 (0.0%)
# healthliteracy_challenges_flag
# 0    38755
# 1    12933
# Name: count, dtype: int64
#
# Rate of 1/Yes: 25.0%

# %% [markdown]
# ### opioid_flag

# %%
col = 'opioid_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === opioid_flag ===
# Missing: 0 (0.0%)
# opioid_flag
# 0    40728
# 1    10960
# Name: count, dtype: int64
#
# Rate of 1/Yes: 21.2%

# %% [markdown]
# ### polypharmacy_flag

# %%
col = 'polypharmacy_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === polypharmacy_flag ===
# Missing: 1236 (2.4%)
# polypharmacy_flag
# 0.0    35718
# 1.0    14734
# NaN     1236
# Name: count, dtype: int64
#
# Rate of 1/Yes: 29.2%

# %% [markdown]
# ### dual_elg

# %%
col = 'dual_elg'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === dual_elg ===
# Missing: 0 (0.0%)
# dual_elg
# 1    50206
# 0     1482
# Name: count, dtype: int64
#
# Rate of 1/Yes: 97.1%

# %% [markdown]
# ### Engaged_flag

# %%
col = 'Engaged_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === Engaged_flag ===
# Missing: 50664 (98.0%)
# Engaged_flag
# NaN    50664
# 1.0     1024
# Name: count, dtype: int64
#
# Rate of 1/Yes: 100.0%

# %% [markdown]
# ### OptOut_flag

# %%
col = 'OptOut_flag'
df[col] = pd.to_numeric(df[col], errors='coerce')
print(f'=== {col} ===')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts(dropna=False)
print(vc)
print(f'\nRate of 1/Yes: {df[col].dropna().mean()*100:.1f}%' if pd.api.types.is_numeric_dtype(df[col]) else '')
plt.figure(figsize=(6, 3))
vc.plot(kind='bar', edgecolor='white')
plt.title(f'{col} value counts')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# === OptOut_flag ===
# Missing: 50479 (97.7%)
# OptOut_flag
# NaN    50479
# 1.0     1209
# Name: count, dtype: int64
#
# Rate of 1/Yes: 100.0%

# %% [markdown]
# ---
# ## Categorical / Text Variables

# %% [markdown]
# ### member_id

# %%
col = 'member_id'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
print('(Skipping detailed analysis for member_id — unique identifier)')
# Out:
# === member_id ===
# Unique values: 51652
# Missing: 0 (0.0%)
# (Skipping detailed analysis for member_id — unique identifier)

# %% [markdown]
# ### client_contract

# %%
col = 'client_contract'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === client_contract ===
# Unique values: 6
# Missing: 0 (0.0%)
# Top 10 values:
# client_contract
# The Funds 93 PRE    36475
# The Funds 93         6407
# The Funds 92         5142
# The Funds CM         2731
# The Funds PR          753
# The Funds 93 ALT      180
# Name: count, dtype: int64

# %% [markdown]
# ### gender

# %%
col = 'gender'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === gender ===
# Unique values: 2
# Missing: 0 (0.0%)
# Top 10 values:
# gender
# F    27781
# M    23907
# Name: count, dtype: int64

# %% [markdown]
# ### date_of_death

# %%
col = 'date_of_death'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === date_of_death ===
# Unique values: 582
# Missing: 48362 (93.6%)
# Top 10 values:
# date_of_death
# 3/27/2025     15
# 2/20/2025     15
# 11/12/2025    14
# 1/20/2025     14
# 2/22/2025     14
# 1/25/2026     13
# 2/7/2025      13
# 12/21/2025    12
# 10/31/2025    12
# 12/26/2025    12
# Name: count, dtype: int64

# %% [markdown]
# ### County

# %%
col = 'County'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === County ===
# Unique values: 748
# Missing: 0 (0.0%)
# Top 10 values:
# County
# MARION        2937
# FAYETTE       2256
# JEFFERSON     2211
# BELMONT       1908
# RALEIGH       1827
# BOONE         1519
# GREENE        1505
# MARSHALL      1395
# LOGAN         1259
# MONONGALIA    1250
# Name: count, dtype: int64

# %% [markdown]
# ### State

# %%
col = 'State'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === State ===
# Unique values: 51
# Missing: 0 (0.0%)
# Top 10 values:
# State
# WV    19824
# PA     6029
# OH     4833
# IL     4419
# AL     3930
# KY     3802
# VA     2034
# IN     1958
# UT      919
# AZ      728
# Name: count, dtype: int64

# %% [markdown]
# ### plan_type

# %%
col = 'plan_type'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === plan_type ===
# Unique values: 1
# Missing: 0 (0.0%)
# Top 10 values:
# plan_type
# Federal    51688
# Name: count, dtype: int64

# %% [markdown]
# ### risk_tier

# %%
col = 'risk_tier'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === risk_tier ===
# Unique values: 5
# Missing: 1236 (2.4%)
# Top 10 values:
# risk_tier
# 1.0    25188
# 2.0    15141
# 3.0     7586
# 4.0     2026
# 5.0      511
# Name: count, dtype: int64

# %% [markdown]
# ### program

# %%
col = 'program'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === program ===
# Unique values: 1
# Missing: 49455 (95.7%)
# Top 10 values:
# program
# CaseManagement    2233
# Name: count, dtype: int64

# %% [markdown]
# ### ProgramStart

# %%
col = 'ProgramStart'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === ProgramStart ===
# Unique values: 413
# Missing: 49455 (95.7%)
# Top 10 values:
# ProgramStart
# 5/20/2024    23
# 3/6/2024     21
# 2/15/2024    20
# 2/5/2024     18
# 4/9/2024     17
# 2/12/2024    16
# 5/29/2024    16
# 1/16/2024    15
# 1/18/2024    15
# 5/10/2024    15
# Name: count, dtype: int64

# %% [markdown]
# ### ProgramEnd

# %%
col = 'ProgramEnd'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === ProgramEnd ===
# Unique values: 269
# Missing: 49455 (95.7%)
# Top 10 values:
# ProgramEnd
# 3/6/2024     23
# 7/16/2024    21
# 9/10/2024    19
# 2/15/2024    18
# 5/20/2024    18
# 1/2/2024     17
# 2/5/2024     17
# 12/9/2024    16
# 4/17/2024    16
# 4/9/2024     16
# Name: count, dtype: int64

# %% [markdown]
# ### engaged_date

# %%
col = 'engaged_date'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === engaged_date ===
# Unique values: 316
# Missing: 50664 (98.0%)
# Top 10 values:
# engaged_date
# 1/18/2024     14
# 12/7/2023     12
# 2/5/2024      10
# 1/22/2024     10
# 4/3/2024      10
# 10/16/2023     9
# 8/16/2023      9
# 3/13/2024      9
# 2/7/2024       9
# 1/9/2024       9
# Name: count, dtype: int64

# %% [markdown]
# ### case_manager_name

# %%
col = 'case_manager_name'
print(f'=== {col} ===')
print(f'Unique values: {df[col].nunique()}')
print(f'Missing: {df[col].isna().sum()} ({df[col].isna().mean()*100:.1f}%)')
vc = df[col].value_counts()
print(f'Top 10 values:')
print(vc.head(10))
if df[col].nunique() <= 20:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15)')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    plt.figure(figsize=(8, 3.5))
    vc.head(15).plot(kind='bar', edgecolor='white')
    plt.title(f'{col} value counts (top 15 of {df[col].nunique()})')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# === case_manager_name ===
# Unique values: 73
# Missing: 51093 (98.8%)
# Top 10 values:
# case_manager_name
# Kirk, Charlene         151
# Adkins, Virginia        83
# Helton, Ocie            33
# Burchett, Debra         31
# Washington, Natalie     22
# Comer, Jinny            19
# Burke, Tiffany          17
# Elliott, Juanita        16
# Willett, Sharon         12
# Tackett, Betty          10
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Data Review Summary

# %%
n_rows = len(df)
n_cols = len(df.columns)

# Classify variables
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
binary_cols = [c for c in df.columns if df[c].dropna().nunique() <= 2 and c in numeric_cols]
continuous_cols = [c for c in numeric_cols if c not in binary_cols]
categorical_cols = [c for c in df.columns if c not in numeric_cols]

summary = pd.DataFrame({
    'Metric': [
        'Total rows', 'Total columns',
        'Numeric columns', 'Binary/indicator columns', 'Continuous/count columns',
        'Categorical/text columns', 'Date columns',
        'Columns with >50% missing', 'Columns with zero missing',
        'Mean missingness rate across all columns',
    ],
    'Value': [
        f'{n_rows:,}', n_cols,
        len(numeric_cols), len(binary_cols), len(continuous_cols),
        len(categorical_cols), sum(1 for c in df.columns if 'date' in c.lower() or 'start' in c.lower() or 'end' in c.lower()),
        sum(1 for c in df.columns if df[c].isna().mean() > 0.5),
        sum(1 for c in df.columns if df[c].isna().sum() == 0),
        f"{df.isna().mean().mean()*100:.1f}%",
    ]
})
display(summary)
# Out:
#                                      Metric   Value
# 0                                Total rows  51,688
# 1                             Total columns      56
# 2                           Numeric columns      44
# 3                  Binary/indicator columns      22
# 4                  Continuous/count columns      22
# 5                  Categorical/text columns      12
# 6                              Date columns       5
# 7                 Columns with >50% missing      23
# 8                 Columns with zero missing      26
# 9  Mean missingness rate across all columns   40.3%
